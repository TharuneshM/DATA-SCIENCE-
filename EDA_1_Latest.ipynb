# %% [markdown]
# # Exploratory Data Analysis

# %%
# !pip install pandas_profiling
# !pip install sweetviz
# Out:
# Requirement already satisfied: pandas_profiling in d:\new folder\lib\site-packages (3.5.0)
# Requirement already satisfied: matplotlib<3.7,>=3.2 in d:\new folder\lib\site-packages (from pandas_profiling) (3.5.2)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in d:\new folder\lib\site-packages (from pandas_profiling) (0.7.5)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in d:\new folder\lib\site-packages (from pandas_profiling) (1.21.5)
# Requirement already satisfied: htmlmin==0.1.12 in d:\new folder\lib\site-packages (from pandas_profiling) (0.1.12)
# Requirement already satisfied: pydantic<1.11,>=1.8.1 in d:\new folder\lib\site-packages (from pandas_profiling) (1.10.2)
# Requirement already satisfied: scipy<1.10,>=1.4.1 in d:\new folder\lib\site-packages (from pandas_profiling) (1.9.1)
# Requirement already satisfied: multimethod<1.10,>=1.4 in d:\new folder\lib\site-packages (from pandas_profiling) (1.9)
# Requirement already satisfied: requests<2.29,>=2.24.0 in d:\new folder\lib\site-packages (from pandas_profiling) (2.28.1)
# Requirement already satisfied: typeguard<2.14,>=2.13.2 in d:\new folder\lib\site-packages (from pandas_profiling) (2.13.3)
# Requirement already satisfied: statsmodels<0.14,>=0.13.2 in d:\new folder\lib\site-packages (from pandas_profiling) (0.13.2)
# Requirement already satisfied: tqdm<4.65,>=4.48.2 in d:\new folder\lib\site-packages (from pandas_profiling) (4.64.1)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in d:\new folder\lib\site-packages (from pandas_profiling) (0.11.2)
# Requirement already satisfied: pandas!=1.4.0,<1.6,>1.1 in d:\new folder\lib\site-packages (from pandas_profiling) (1.4.4)
# Requirement already satisfied: phik<0.13,>=0.11.1 in d:\new folder\lib\site-packages (from pandas_profiling) (0.12.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in d:\new folder\lib\site-packages (from pandas_profiling) (6.0)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in d:\new folder\lib\site-packages (from pandas_profiling) (2.11.3)
# Requirement already satisfied: networkx>=2.4 in d:\new folder\lib\site-packages (from visions[type_image_path]==0.7.5->pandas_profiling) (2.8.4)
# Requirement already satisfied: attrs>=19.3.0 in d:\new folder\lib\site-packages (from visions[type_image_path]==0.7.5->pandas_profiling) (21.4.0)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in d:\new folder\lib\site-packages (from visions[type_image_path]==0.7.5->pandas_profiling) (0.2.0)
# Requirement already satisfied: imagehash in d:\new folder\lib\site-packages (from visions[type_image_path]==0.7.5->pandas_profiling) (4.3.1)
# Requirement already satisfied: Pillow in d:\new folder\lib\site-packages (from visions[type_image_path]==0.7.5->pandas_profiling) (9.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\new folder\lib\site-packages (from jinja2<3.2,>=2.11.1->pandas_profiling) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in d:\new folder\lib\site-packages (from matplotlib<3.7,>=3.2->pandas_profiling) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in d:\new folder\lib\site-packages (from matplotlib<3.7,>=3.2->pandas_profiling) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\new folder\lib\site-packages (from matplotlib<3.7,>=3.2->pandas_profiling) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in d:\new folder\lib\site-packages (from matplotlib<3.7,>=3.2->pandas_profiling) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\new folder\lib\site-packages (from matplotlib<3.7,>=3.2->pandas_profiling) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\new folder\lib\site-packages (from matplotlib<3.7,>=3.2->pandas_profiling) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in d:\new folder\lib\site-packages (from pandas!=1.4.0,<1.6,>1.1->pandas_profiling) (2022.1)
# Requirement already satisfied: joblib>=0.14.1 in d:\new folder\lib\site-packages (from phik<0.13,>=0.11.1->pandas_profiling) (1.1.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in d:\new folder\lib\site-packages (from pydantic<1.11,>=1.8.1->pandas_profiling) (4.3.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\new folder\lib\site-packages (from requests<2.29,>=2.24.0->pandas_profiling) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in d:\new folder\lib\site-packages (from requests<2.29,>=2.24.0->pandas_profiling) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in d:\new folder\lib\site-packages (from requests<2.29,>=2.24.0->pandas_profiling) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\new folder\lib\site-packages (from requests<2.29,>=2.24.0->pandas_profiling) (2.0.4)
# Requirement already satisfied: patsy>=0.5.2 in d:\new folder\lib\site-packages (from statsmodels<0.14,>=0.13.2->pandas_profiling) (0.5.2)
# Requirement already satisfied: colorama in d:\new folder\lib\site-packages (from tqdm<4.65,>=4.48.2->pandas_profiling) (0.4.5)
# Requirement already satisfied: six in d:\new folder\lib\site-packages (from patsy>=0.5.2->statsmodels<0.14,>=0.13.2->pandas_profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in d:\new folder\lib\site-packages (from imagehash->visions[type_image_path]==0.7.5->pandas_profiling) (1.3.0)
# Requirement already satisfied: sweetviz in d:\new folder\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy>=1.16.0 in d:\new folder\lib\site-packages (from sweetviz) (1.21.5)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in d:\new folder\lib\site-packages (from sweetviz) (1.4.4)
# Requirement already satisfied: tqdm>=4.43.0 in d:\new folder\lib\site-packages (from sweetviz) (4.64.1)
# Requirement already satisfied: matplotlib>=3.1.3 in d:\new folder\lib\site-packages (from sweetviz) (3.5.2)
# Requirement already satisfied: jinja2>=2.11.1 in d:\new folder\lib\site-packages (from sweetviz) (2.11.3)
# Requirement already satisfied: scipy>=1.3.2 in d:\new folder\lib\site-packages (from sweetviz) (1.9.1)
# Requirement already satisfied: importlib-resources>=1.2.0 in d:\new folder\lib\site-packages (from sweetviz) (5.10.0)
# Requirement already satisfied: zipp>=3.1.0 in d:\new folder\lib\site-packages (from importlib-resources>=1.2.0->sweetviz) (3.8.0)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\new folder\lib\site-packages (from jinja2>=2.11.1->sweetviz) (2.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\new folder\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in d:\new folder\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\new folder\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in d:\new folder\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in d:\new folder\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\new folder\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in d:\new folder\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (9.2.0)
# Requirement already satisfied: pytz>=2020.1 in d:\new folder\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2022.1)
# Requirement already satisfied: colorama in d:\new folder\lib\site-packages (from tqdm>=4.43.0->sweetviz) (0.4.5)
# Requirement already satisfied: six>=1.5 in d:\new folder\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.16.0)

# %%
#load the libraries
import pandas as pd
import numpy as np
import pandas_profiling as pp
import sweetviz as sv

# %%
data1 = pd.read_csv("data_clean.csv")

# %%
data1.head(5)
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0           1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1           2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2           3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3           4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4           5    NaN      NaN  14.3     56     5    5  2010    56       S

# %%
data1.tail(10)
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 148         149   30.0    193.0   6.9     70     9   26  2010    70       C
# 149         150    NaN    145.0  13.2     77     9   27  2010    77      PS
# 150         151   14.0    191.0  14.3     75     9   28  2010    75       S
# 151         152   18.0    131.0   8.0     76     9   29  2010    76      PS
# 152         153   20.0    223.0  11.5     68     9   30  2010    68       S
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C

# %%
data1
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
#Data Structure 

data1.shape
# Out:
# (158, 10)

# %%
#data types
data1.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %% [markdown]
# # Data type conversion

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
data1
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data2=data1.iloc[:,1:]

# %%
data2
# Out:
#      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     67     5    1  2010    67       S
# 1     36.0    118.0   8.0     72     5    2  2010    72       C
# 2     12.0    149.0  12.6     74     5    3  2010    74      PS
# 3     18.0    313.0  11.5     62     5    4  2010    62       S
# 4      NaN      NaN  14.3     56     5    5  2010    56       S
# ..     ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     67     5    1  2010    67       C
# 154   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155    NaN    145.0  13.2     77     9   27  2010    77       S
# 156   14.0    191.0  14.3     75     9   28  2010    75       S
# 157   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
#The method .copy() is used here so that any changes made in new DataFrame don't get reflected in the original one
data=data2.copy()

# %%
data['Month']=pd.to_numeric(data['Month'],errors='coerce')
data['Temp C']=pd.to_numeric(data['Temp C'],errors='coerce')# coerce will introduce NA values for non numeric data in the columns
data['Weather']=data['Weather'].astype('category')           #data['Wind']=data['Wind'].astype('int64')
data
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    67.0    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    72.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    74.0    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    62.0    5.0    4  2010    62       S
# 4      NaN      NaN  14.3    56.0    5.0    5  2010    56       S
# ..     ...      ...   ...     ...    ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4    67.0    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    70.0    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2    77.0    9.0   27  2010    77       S
# 156   14.0    191.0  14.3    75.0    9.0   28  2010    75       S
# 157   18.0    131.0   8.0    76.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Temp C   157 non-null    float64
#  4   Month    157 non-null    float64
#  5   Day      158 non-null    int64
#  6   Year     158 non-null    int64
#  7   Temp     158 non-null    int64
#  8   Weather  155 non-null    category
# dtypes: category(1), float64(5), int64(3)
# memory usage: 10.3 KB

# %% [markdown]
# # Duplicates

# %%
#Count of duplicated rows
data[data.duplicated()].shape
# Out:
# (1, 9)

# %%
data
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    67.0    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    72.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    74.0    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    62.0    5.0    4  2010    62       S
# 4      NaN      NaN  14.3    56.0    5.0    5  2010    56       S
# ..     ...      ...   ...     ...    ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4    67.0    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    70.0    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2    77.0    9.0   27  2010    77       S
# 156   14.0    191.0  14.3    75.0    9.0   28  2010    75       S
# 157   18.0    131.0   8.0    76.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
#Print the duplicated rows
data[data.duplicated()]
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 156   14.0    191.0  14.3    75.0    9.0   28  2010    75       S

# %%
data_cleaned1=data.drop_duplicates()

# %%
data_cleaned1.shape
# Out:
# (157, 9)

# %% [markdown]
# # Drop columns

# %%
data_cleaned2=data_cleaned1.drop('Temp C',axis=1)

# %%
data_cleaned2
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    5.0    4  2010    62       S
# 4      NaN      NaN  14.3    5.0    5  2010    56       S
# ..     ...      ...   ...    ...  ...   ...   ...     ...
# 152   20.0    223.0  11.5    9.0   30  2010    68       S
# 153   41.0    190.0   7.4    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2    9.0   27  2010    77       S
# 157   18.0    131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %% [markdown]
# # Rename the columns

# %%
#rename the Solar column
data_cleaned3 = data_cleaned2.rename({'Solar.R': 'Solar'}, axis=1)

# %%
data_cleaned3
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4    5.0    1  2010    67       S
# 1     36.0  118.0   8.0    5.0    2  2010    72       C
# 2     12.0  149.0  12.6    5.0    3  2010    74      PS
# 3     18.0  313.0  11.5    5.0    4  2010    62       S
# 4      NaN    NaN  14.3    5.0    5  2010    56       S
# ..     ...    ...   ...    ...  ...   ...   ...     ...
# 152   20.0  223.0  11.5    9.0   30  2010    68       S
# 153   41.0  190.0   7.4    5.0    1  2010    67       C
# 154   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155    NaN  145.0  13.2    9.0   27  2010    77       S
# 157   18.0  131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %% [markdown]
# # Outlier Detection

# %%
# histogram of Ozone
import matplotlib.pyplot as plt
plt.hist(data_cleaned3["Ozone"])
# Out:
# (array([28., 36., 21.,  9., 11.,  7.,  3.,  2.,  1.,  1.]),
#  array([  1. ,  17.7,  34.4,  51.1,  67.8,  84.5, 101.2, 117.9, 134.6,
#         151.3, 168. ]),
#  <BarContainer object of 10 artists>)

# %%
#Box plot
data_cleaned3["Ozone"].plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
#Descriptive stat
data_cleaned3['Ozone'].describe()
# Out:
# count    119.000000
# mean      41.815126
# std       32.659249
# min        1.000000
# 25%       18.000000
# 50%       31.000000
# 75%       62.000000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
data_cleaned3
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4    5.0    1  2010    67       S
# 1     36.0  118.0   8.0    5.0    2  2010    72       C
# 2     12.0  149.0  12.6    5.0    3  2010    74      PS
# 3     18.0  313.0  11.5    5.0    4  2010    62       S
# 4      NaN    NaN  14.3    5.0    5  2010    56       S
# ..     ...    ...   ...    ...  ...   ...   ...     ...
# 152   20.0  223.0  11.5    9.0   30  2010    68       S
# 153   41.0  190.0   7.4    5.0    1  2010    67       C
# 154   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155    NaN  145.0  13.2    9.0   27  2010    77       S
# 157   18.0  131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
#Bar plot
data['Weather'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Missing Values and Imputation

# %%
import seaborn as sns
cols = data_cleaned3.columns 
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(data_cleaned3[cols].isnull(),
            cmap=sns.color_palette(colours))
# Out:
# <AxesSubplot:>

# %%
data_cleaned3[data_cleaned3.isnull().any(axis=1)].head()
# Out:
#     Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 4     NaN    NaN  14.3    5.0    5  2010    56       S
# 5    28.0    NaN  14.9    5.0    6  2010    66       C
# 9     NaN  194.0   8.6    5.0   10  2010    69       S
# 10    7.0    NaN   6.9    5.0   11  2010    74       C
# 23   32.0   92.0  12.0    NaN   24  2010    61       C

# %%
data_cleaned3.isnull().sum()
# Out:
# Ozone      38
# Solar       7
# Wind        0
# Month       1
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
#Mean Imputation
mean = data_cleaned3['Ozone'].mean()
print(mean)
# Out:
# 41.81512605042017

# %%
data_cleaned3['Ozone'] = data_cleaned3['Ozone'].fillna(mean)

# %%
data_cleaned3
# Out:
#          Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0    41.000000  190.0   7.4    5.0    1  2010    67       S
# 1    36.000000  118.0   8.0    5.0    2  2010    72       C
# 2    12.000000  149.0  12.6    5.0    3  2010    74      PS
# 3    18.000000  313.0  11.5    5.0    4  2010    62       S
# 4    41.815126    NaN  14.3    5.0    5  2010    56       S
# ..         ...    ...   ...    ...  ...   ...   ...     ...
# 152  20.000000  223.0  11.5    9.0   30  2010    68       S
# 153  41.000000  190.0   7.4    5.0    1  2010    67       C
# 154  30.000000  193.0   6.9    9.0   26  2010    70      PS
# 155  41.815126  145.0  13.2    9.0   27  2010    77       S
# 157  18.000000  131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
mean_solar=data_cleaned3["Solar"].mean()
mean_solar
# Out:
# 185.36666666666667

# %%
data_cleaned3["Solar"]=data_cleaned3["Solar"].fillna(mean_solar)
data_cleaned3
# Out:
#          Ozone       Solar  Wind  Month  Day  Year  Temp Weather
# 0    41.000000  190.000000   7.4    5.0    1  2010    67       S
# 1    36.000000  118.000000   8.0    5.0    2  2010    72       C
# 2    12.000000  149.000000  12.6    5.0    3  2010    74      PS
# 3    18.000000  313.000000  11.5    5.0    4  2010    62       S
# 4    41.815126  185.366667  14.3    5.0    5  2010    56       S
# ..         ...         ...   ...    ...  ...   ...   ...     ...
# 152  20.000000  223.000000  11.5    9.0   30  2010    68       S
# 153  41.000000  190.000000   7.4    5.0    1  2010    67       C
# 154  30.000000  193.000000   6.9    9.0   26  2010    70      PS
# 155  41.815126  145.000000  13.2    9.0   27  2010    77       S
# 157  18.000000  131.000000   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
data_cleaned3.isnull().sum()
# Out:
# Ozone      0
# Solar      0
# Wind       0
# Month      1
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %%
#Missing value imputation for categorical vlaue
#Get the object columns
data_cleaned3["Weather"]=data_cleaned3["Weather"].fillna(data_cleaned3["Weather"].mode())
data_cleaned3["Weather"]
# Out:
# 0       S
# 1       C
# 2      PS
# 3       S
# 4       S
#        ..
# 152     S
# 153     C
# 154    PS
# 155     S
# 157     C
# Name: Weather, Length: 157, dtype: category
# Categories (3, object): ['C', 'PS', 'S']

# %%
#Missing value imputation for categorical vlaue by assigning the column to a seperate variable
#Get the object columns
obj_columns=data_cleaned3[['Weather']]

# %%
obj_columns.isnull().sum()
# Out:
# Weather    3
# dtype: int64

# %%
#Missing value imputation for categorical vlaue
obj_columns=obj_columns.fillna(obj_columns.mode())

# %%
obj_columns.isnull().sum()
# Out:
# Weather    0
# dtype: int64

# %%
data_cleaned3.shape
# Out:
# (157, 8)

# %%
obj_columns.shape
# Out:
# (157, 1)

# %%
#Join the data set with imputed object dataset
data_cleaned4=pd.concat([data_cleaned3,obj_columns],axis=1)

# %%
data_cleaned4.isnull().sum()
data_cleaned4
# Out:
#          Ozone       Solar  Wind  Month  Day  Year  Temp Weather Weather
# 0    41.000000  190.000000   7.4    5.0    1  2010    67       S       S
# 1    36.000000  118.000000   8.0    5.0    2  2010    72       C       C
# 2    12.000000  149.000000  12.6    5.0    3  2010    74      PS      PS
# 3    18.000000  313.000000  11.5    5.0    4  2010    62       S       S
# 4    41.815126  185.366667  14.3    5.0    5  2010    56       S       S
# ..         ...         ...   ...    ...  ...   ...   ...     ...     ...
# 152  20.000000  223.000000  11.5    9.0   30  2010    68       S       S
# 153  41.000000  190.000000   7.4    5.0    1  2010    67       C       C
# 154  30.000000  193.000000   6.9    9.0   26  2010    70      PS      PS
# 155  41.815126  145.000000  13.2    9.0   27  2010    77       S       S
# 157  18.000000  131.000000   8.0    9.0   29  2010    76       C       C
#
# [157 rows x 9 columns]

# %% [markdown]
# # Scatter plot and Correlation analysis

# %%
# Seaborn visualization library
import seaborn as sns
# Create the default pairplot
sns.pairplot(data_cleaned3)

# %%
#Correlation
data_cleaned3.corr()
# Out:
#           Ozone     Solar      Wind     Month       Day  Year      Temp
# Ozone  1.000000  0.304559 -0.520004  0.132860 -0.021916   NaN  0.606500
# Solar  0.304559  1.000000 -0.055874 -0.090902 -0.151007   NaN  0.260677
# Wind  -0.520004 -0.055874  1.000000 -0.166216  0.029900   NaN -0.441228
# Month  0.132860 -0.090902 -0.166216  1.000000  0.050055   NaN  0.398516
# Day   -0.021916 -0.151007  0.029900  0.050055  1.000000   NaN -0.122787
# Year        NaN       NaN       NaN       NaN       NaN   NaN       NaN
# Temp   0.606500  0.260677 -0.441228  0.398516 -0.122787   NaN  1.000000

# %% [markdown]
# # Transformations

# %% [markdown]
# #### Dummy Variable

# %%
#Creating dummy variable for Weather column
data_cleaned4=pd.get_dummies(data_cleaned4,columns=['Weather'])

# %%
data_cleaned4
# Out:
#          Ozone       Solar  Wind  Month  Day  Year  Temp  Weather_C  \
# 0    41.000000  190.000000   7.4    5.0    1  2010    67          0
# 1    36.000000  118.000000   8.0    5.0    2  2010    72          1
# 2    12.000000  149.000000  12.6    5.0    3  2010    74          0
# 3    18.000000  313.000000  11.5    5.0    4  2010    62          0
# 4    41.815126  185.366667  14.3    5.0    5  2010    56          0
# ..         ...         ...   ...    ...  ...   ...   ...        ...
# 152  20.000000  223.000000  11.5    9.0   30  2010    68          0
# 153  41.000000  190.000000   7.4    5.0    1  2010    67          1
# 154  30.000000  193.000000   6.9    9.0   26  2010    70          0
# 155  41.815126  145.000000  13.2    9.0   27  2010    77          0
# 157  18.000000  131.000000   8.0    9.0   29  2010    76          1
#
#      Weather_PS  Weather_S  Weather_C  Weather_PS  Weather_S
# 0             0          1          0           0          1
# 1             0          0          1           0          0
# 2             1          0          0           1          0
# 3             0          1          0           0          1
# 4             0          1          0           0          1
# ..          ...        ...        ...         ...        ...
# 152           0          1          0           0          1
# 153           0          0          1           0          0
# 154           1          0          0           1          0
# 155           0          1          0           0          1
# 157           0          0          1           0          0
#
# [157 rows x 13 columns]

# %%
data_cleaned4=data_cleaned4.dropna()

# %% [markdown]
# #### Normalization of the data

# %%
#Normalization of the data
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

# %%
data_cleaned4.values
# Out:
# array([[ 41.  , 190.  ,   7.4 , ...,   0.  ,   0.  ,   1.  ],
#        [ 36.  , 118.  ,   8.  , ...,   1.  ,   0.  ,   0.  ],
#        [ 12.  , 149.  ,  12.6 , ...,   0.  ,   1.  ,   0.  ],
#        ...,
#        [ 30.  , 193.  ,   6.9 , ...,   0.  ,   1.  ,   0.  ],
#        [ 41.82, 145.  ,  13.2 , ...,   0.  ,   0.  ,   1.  ],
#        [ 18.  , 131.  ,   8.  , ...,   1.  ,   0.  ,   0.  ]])

# %%
array = data_cleaned3.values

scaler = MinMaxScaler(feature_range=(0,1))
rescaledX = scaler.fit_transform(array[:,0:5])

#transformed data
set_printoptions(precision=2)
print(rescaledX[0:5,:])
# Out:
# [[0.24 0.56 0.3  0.   0.  ]
#  [0.21 0.34 0.33 0.   0.03]
#  [0.07 0.43 0.57 0.   0.07]
#  [0.1  0.94 0.52 0.   0.1 ]
#  [0.24 0.55 0.66 0.   0.13]]

# %%
# Standardize data (0 mean, 1 stdev)
from sklearn.preprocessing import StandardScaler

# %%
array = data_cleaned4.values
scaler = StandardScaler().fit(array)
rescaledX = scaler.transform(array)

# summarize transformed data
set_printoptions(precision=2)
print(rescaledX[0:5,:])
# Out:
# [[-3.09e-02  4.66e-02 -7.19e-01 -1.43e+00 -1.66e+00  0.00e+00 -1.17e+00
#   -6.67e-01 -6.57e-01  1.30e+00 -6.67e-01 -6.57e-01  1.25e+00]
#  [-2.07e-01 -7.84e-01 -5.47e-01 -1.43e+00 -1.55e+00  0.00e+00 -6.29e-01
#    1.50e+00 -6.57e-01 -7.69e-01  1.50e+00 -6.57e-01 -8.01e-01]
#  [-1.05e+00 -4.26e-01  7.66e-01 -1.43e+00 -1.44e+00  0.00e+00 -4.14e-01
#   -6.67e-01  1.52e+00 -7.69e-01 -6.67e-01  1.52e+00 -8.01e-01]
#  [-8.41e-01  1.47e+00  4.52e-01 -1.43e+00 -1.33e+00  0.00e+00 -1.70e+00
#   -6.67e-01 -6.57e-01  1.30e+00 -6.67e-01 -6.57e-01  1.25e+00]
#  [-2.22e-03 -6.91e-03  1.25e+00 -1.43e+00 -1.22e+00  0.00e+00 -2.35e+00
#   -6.67e-01 -6.57e-01  1.30e+00 -6.67e-01 -6.57e-01  1.25e+00]]

# %% [markdown]
# # Speed up the EDA process

# %%
EDA_report= pp.ProfileReport(data)
EDA_report.to_file(output_file='report.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
sweet_report = sv.analyze(data)
sweet_report.show_html('weather_report.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report weather_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
